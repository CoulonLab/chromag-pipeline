# %%
from scipy import *
from matplotlib import pyplot as plt
import os

# %%
basePath='E:/Coulon_data/CoulonLab Dropbox/data/Lorena/Chr1/190626/Analysis2h_190626_sgRNA130_2/'

lfn=['MAX_190626_dCas9JF646-sg130_2-cell1_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell2_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell2_off0_nrmd_s2.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell2_off0_nrmd_s3.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell2_off0_nrmd_s4.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell3_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell3_off0_nrmd_s2.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell3_off0_nrmd_s3.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell3_off0_nrmd_s4.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell4_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell4_off0_nrmd_s2.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell5_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell5_off0_nrmd_s2.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell6_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell7_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell7_off0_nrmd_s2.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell8_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell8_off0_nrmd_s2.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell9_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell9_off0_nrmd_s2.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell10_off0_nrmd_s1.trk2',
     'MAX_190626_dCas9JF646-sg130_2-cell12_off0_nrmd_s1.trk2',
     ]

traces=array([loadtxt(basePath+fn) for fn in lfn])

# %%
traces.shape
# Out:
# (22, 30, 6)

# %%
for i in range(traces.shape[0]):
    plt.plot(traces[i,:,0],traces[i,:,-2]/1e3)
plt.xlabel('Time (frames)'); plt.ylabel('Fluo. (a.u.)');
#plt.yscale('log')
plt.show()
